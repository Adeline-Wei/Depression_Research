# %%
import re, math
import operator
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cross_validation import StratifiedShuffleSplit
from random import randint
import ipynb.fs.defs.PeopleInfo as peopleInfo
from nltk.corpus import stopwords
from nltk import TweetTokenizer
from nltk import PorterStemmer
# import ipynb.fs.defs.TweetTextHandler as tweetTextHandler
import ipynb.fs.defs.FilterMethods as filterMethods
import sys, os
sys.path.append('../2_feature')
import ipynb.fs.defs.GetFeatures as getFeatures
global stop_words
stop_words = stopwords.words('english')
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from IPython.display import display, Image
plotly.tools.set_credentials_file(username='Adeline', api_key='Z5eltNtBQXqvI05ZFQtz')
# import plotly.offline as offline
# offline.init_notebook_mode(connected=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def replace_by_symbols(txt):
#     txt = re.sub(r"https\S+", 'URL', txt)
#     txt = re.sub(r"http\S+", 'URL', txt)
#     txt = re.sub(r"pic.twitter.com\S+", 'URL', txt)
#     txt = re.sub(r"twitter.com/\S+", 'URL', txt)
#     txt = re.sub(r"\S+/\S+", 'URL', txt)
#     txt = re.sub(r"@\S+", 'USERMENTION', txt)
#     txt = re.sub(r"#\S+", 'HASHTAG', txt)
    txt = txt.lower()
    txt = re.sub(r"https\S+", '', txt)
    txt = re.sub(r"http\S+", '', txt)
    txt = re.sub(r"pic.twitter.com\S+", '', txt)
    txt = re.sub(r"twitter.com/\S+", '', txt)
    txt = re.sub(r"\S+/\S+", '', txt)
    txt = re.sub(r"@\S+", '', txt)
    txt = re.sub(r"#\S+", '', txt)
    txt = re.sub(r"idk", 'i do not know', txt)   # idk: i don't know
    txt = re.sub(r"tho", 'though', txt)   # tho
    txt = re.sub(r"i\'m", 'i am', txt)
    txt = re.sub(r"you\'re", 'you are', txt)
    txt = re.sub(r"he\'s", 'he is', txt)
    txt = re.sub(r"she\'s", 'she is', txt)
    txt = re.sub(r"it\'s", 'it is', txt)
    txt = re.sub(r"we\'re", 'we are', txt)
    txt = re.sub(r"they\'re", 'they are', txt)
    txt = re.sub(r"isn\'t", 'is not', txt)
    txt = re.sub(r"don\'t", 'do not', txt)
    txt = re.sub(r"doesn\'t", 'does not', txt)
    txt = re.sub(r"didn\'t", 'did not', txt)
    txt = re.sub(r"wasn\'t", 'was not', txt)
    txt = re.sub(r"weren\'t", 'were not', txt)
    txt = re.sub(r"haven\'t", 'have not', txt)
    txt = re.sub(r"can\'t", 'can not', txt)
    txt = re.sub(r"couldn\'t", 'could not', txt)
    txt = re.sub(r"wouldn\'t", 'would not', txt)
    txt = re.sub(r"shouldn\'t", 'should not', txt)
    txt = re.sub(r"&amp", '', txt)
    return txt

# %% [markdown]
# # Create LIWC Dictionary

# %%
liwc_category_dict = dict()
liwc_word_dict = dict()
with open('/home/adeline/Documents/Depression_Research/LIWC2007 Documents/Dictionaries/LIWC2007_English080730.dic') as open_file:
    raw_data = open_file.readlines()
    for row in raw_data[1:65]:
        row = row.strip().split('\t')
        liwc_category_dict[row[0]] = row[1]
    for row in raw_data[66:4553]:
        row = row.strip().split('\t')
        liwc_word_dict[row[0]] = row[1:]

# %%
for stop_word in stop_words:
    try:
        print('{0}\t{1}'.format(stop_word, liwc_word_dict[stop_word]))
    except KeyError:
        print('KeyError: {0}'.format(stop_word))
# Out:
# i	['1', '2', '3', '4']
# me	['1', '2', '3', '4']
# my	['1', '2', '3', '4']
# myself	['1', '2', '3', '4']
# we	['1', '2', '3', '5', '121', '131', '138']
# our	['1', '2', '3', '5', '121']
# ours	['1', '2', '3', '5', '121']
# ourselves	['1', '2', '3', '5', '121']
# you	['1', '2', '3', '6', '121']
# your	['1', '2', '3', '6', '121']
# yours	['1', '2', '3', '6', '121']
# KeyError: yourself
# KeyError: yourselves
# he	['1', '2', '3', '7', '121']
# him	['1', '2', '3', '7', '121']
# his	['1', '2', '3', '7', '121']
# himself	['1', '2', '3', '7', '121']
# she	['1', '2', '3', '7', '121']
# her	['1', '2', '3', '7', '121']
# hers	['1', '2', '3', '7', '121']
# herself	['1', '2', '3', '7', '121']
# it	['1', '2', '9']
# its	['1', '2', '9']
# itself	['1', '2', '9']
# they	['1', '2', '3', '8', '121']
# them	['1', '2', '3', '8', '121']
# KeyError: their
# KeyError: theirs
# themselves	['1', '2', '3', '8', '121']
# what	['1', '2', '9']
# which	['1', '2', '9']
# who	['1', '2', '9', '121']
# whom	['1', '2', '9', '121']
# this	['1', '2', '9']
# that	['1', '2', '9']
# these	['1', '2', '9']
# those	['1', '2', '9']
# am	['11', '1', '12', '14']
# is	['11', '1', '12', '14']
# are	['11', '1', '12', '14']
# was	['11', '1', '12', '13']
# were	['11', '1', '12', '13']
# be	['11', '1', '12']
# been	['11', '1', '12', '13']
# being	['11', '1', '12']
# have	['11', '1', '12', '14']
# has	['11', '1', '12', '14']
# had	['11', '1', '12', '13']
# having	['11', '1', '12']
# do	['11', '1', '12', '14']
# does	['11', '1', '12', '14']
# did	['11', '1', '12', '13']
# doing	['11', '1', '12']
# a	['1', '10']
# an	['1', '10']
# the	['1', '10']
# and	['1', '18', '131', '138']
# but	['1', '18', '131', '139']
# if	['1', '18', '131', '134', '135', '139']
# or	['1', '18', '131', '135', '139']
# because	['1', '18', '131', '133']
# as	['1', '17', '18']
# until	['1', '17', '18', '253', '250']
# while	['1', '18', '253', '250']
# of	['1', '17']
# at	['1', '17', '252', '250']
# by	['1', '17']
# for	['1', '17']
# with	['1', '17', '131', '138']
# about	['1', '16', '17']
# against	['1', '17']
# between	['1', '17']
# into	['1', '17', '131', '138', '252', '250']
# KeyError: through
# during	['1', '17', '253', '250']
# before	['1', '17', '253', '250']
# after	['1', '17', '253', '250']
# above	['1', '17', '252', '250']
# below	['1', '17', '252', '250']
# to	['1', '17']
# from	['1', '17']
# up	['1', '17', '252', '250']
# down	['1', '17', '252', '250']
# in	['1', '17', '252', '250']
# out	['1', '17', '131', '138', '252', '250']
# on	['1', '17', '252', '250']
# off	['1', '17', '252', '250']
# over	['1', '17', '252', '250']
# under	['1', '17', '252', '250']
# again	['1', '16', '253', '250']
# KeyError: further
# then	['1', '18', '253', '250']
# once	['1', '21', '253', '250']
# here	['1', '16']
# there	['1', '16']
# when	['1', '18', '253', '250', '16']
# where	['1', '16', '252', '250']
# why	['131', '133']
# how	['1', '16', '18', '131', '133']
# all	['1', '20', '131', '136']
# any	['1', '20', '131', '135']
# both	['1', '20', '131', '138', '252', '250']
# each	['1', '20', '131', '138']
# KeyError: few
# more	['1', '20']
# most	['1', '20', '131', '135']
# other	['1', '2', '9']
# some	['1', '20', '131', '135']
# such	['1', '16']
# no	['1', '19']
# nor	['1', '18', '19']
# not	['1', '19', '131', '139']
# only	['1', '16']
# own	['1', '20']
# same	['131', '1', '20']
# so	['1', '16', '18']
# than	['1', '17']
# too	['1', '16']
# very	['1', '16']
# KeyError: s
# KeyError: t
# can	['11', '1', '12', '14']
# will	['11', '1', '12', '15']
# just	['1', '16', '131', '139']
# KeyError: don
# should	['11', '1', '12', '15', '131', '134']
# now	['1', '16', '253', '250']
# KeyError: d
# KeyError: ll
# KeyError: m
# KeyError: o
# KeyError: re
# KeyError: ve
# KeyError: y
# KeyError: ain
# KeyError: aren
# KeyError: couldn
# KeyError: didn
# KeyError: doesn
# KeyError: hadn
# KeyError: hasn
# KeyError: haven
# KeyError: isn
# ma	['121', '122']
# KeyError: mightn
# KeyError: mustn
# KeyError: needn
# KeyError: shan
# KeyError: shouldn
# KeyError: wasn
# KeyError: weren
# won	['11', '13', '125', '126', '355']
# KeyError: wouldn

# %%
patients = dict()
ordinarys = dict()
with open('../0_dataset/patient_ids') as r:
    for patient in r.readlines()[:100]:
        patient = patient.strip()
        patients[patient] = peopleInfo.Patient(patient)
with open('../0_dataset/ordinary_ids') as r:
    for ordinary in r.readlines()[:100]:
        ordinary = ordinary.strip()
        ordinarys[ordinary] = peopleInfo.Ordinary(ordinary)

# %%
patients = filterMethods.filter_user_by_tweet_number(patients)
ordinarys = filterMethods.filter_user_by_tweet_number(ordinarys)
# Out:
# Remove users:['402683346', '181095972']
# Remove users:[]

# %%
base_texts = []
group_texts = []

for key in patients.keys():
    group_texts.append(replace_by_symbols('\n'.join(patients[key].getText())))

for key in ordinarys.keys():
    base_texts.append(replace_by_symbols('\n'.join(ordinarys[key].getText())))

corpus = base_texts + group_texts

# %%
group_texts[0]
# Out:
# 'I did not recognize the initial symptoms of depression so it took the inability to function for me to see a Dr. who then diagnosed me with it\n    \n    \n \nMental Health Disease is more common than you think.    \nHappy Wednesday, friends!  \n    \nIs Laughter Still the Best Medicine?   via \nIs Laughter Still the Best Medicine?  \n is the best way to lift your mood! Doing something kind and helpful for others, is the perfect...  \n  \n \nYou only have control over yourself and how you choose to be as a person.  \n   \n   \n \nRules for finding happiness!   \nGood morning, beautiful people! Have an amazing day!    \n \n It\'s not about you.  \nHow do we become a wounded healer?     \n \nBelieve In Who You Are!  \n  \n      \n    \nMake it a great Monday! Have a productive week!  \n  \n \nAs you prepare for the upcoming week, remember this ~  \n     \n    \nTake time to enjoy yourself when you are away from work. Release your anxiety & stress. Be present in the moment...  \n   \nHave a beautiful day, friends!  \n   … - I\'ve used the 5,4,3,2,1 technique and found it be be helpful.\nHave you ever tried a Grounding Technique to shift your focus?\nI changed my settings so only friends of friends can send requests because I had gotten friend requests from a few creepers. No thank you.\nPeace be with you as you sleep tonight, and every night.  \nThe best way to overcome "overthinking" is to believe in yourself. Trust your instincts. Follow your heart....  \n \n rainn.org / - Rape, Abuse, & Incest National Network    \n  \nMore than 3 million cases of PTSD are diagnosed per year, in the USA alone. PTSD can be diagnosed and treated by...  \nI posted a new photo to Facebook  \n\nHealthy Tips on how to be Mentally Strong.    \nHave a fantastic weekend! Happy Saturday!  \n \n     \nWhat is your go to comfort food? Please comment and share with us! Mine is definitely Chocolate. Yum!...  \n   \n \nHave a great day, everyone! It\'s Friday!  \nSleep well.  \nPTSD, or Posttraumatic Stress Disorder, is a psychiatric disorder that can occur following the experience or...  \n  \n    \nSo awesome and inspirational. A day thoughse students will never forget.\nI posted a new photo to Facebook  \n  \n  \n \nA relaxing pre-sleep tip!  \nTrust your instincts. Trust your intuition. Follow your heart.   \n \nSpread kindness everywhere! You may just save a life.    \n  \nIntroduce these 5 simple strategies into your life and you will feel the benefits.  \n  \nHappy Wednesday, friends! Embrace the day!  \n \n"Depression disorders make one feel exhausted, worthless, helpless, and hopeless. Such negative thoughughts and...  \n      \nPlease text 741-741 if you are in crisis. Trained counselors are waiting to help you. You are not alone!  ...  \nThis too, shall pass.    \n \n \nDad do you have a few minutes to talk? written by Rick Strait.    \n \nClick "like" if you\'ve experienced this thoughught.    \nDon\'t be so hard on yourself. You are doing the best you can.   \n  \n \n     \nStress less and embrace the goodness the day has to offer!   \nCreate something amazing this week! Happy Wednesday!  \n \n   \nEvery day we need to silence that monster and not give in to the negativity it spews!  ...  \n  \nThere is freedom in forgiveness.  \n \n - Not All Pain Is Physical.  \n \n     \nThank you to Emily for giving me her permission to share her video. She created it to bring attention to issues...  \nPerspective is a gift.   \nEnjoy a relaxing day with friends and family!     \n \nThis mental tug of war is not only frustrating, but draining as well. Making simple decisions or concentrating...  \nPractice  every single day!  \n \n \nHave a wonderful weekend, friends! ~ Kat & Nat  \nPlease remember you are not alone! You matter and your life matters! Please text 741741 if you are in crisis and...  \nJust a friendly reminder ...  \n \n  \n \n    \n    \n  \n    \nHappy Friendship Friday! Share this post with your friends to wish them a HAPPY day!  \nTomorrow  ...

# %%
def tokenize(text):
    text_list = re.findall('(?u)\\b[a-zA-Z]\\w{0,}\\b', text)
    return text_list

# %%
for texts in group_texts:
    for text in texts.split('\n'):
        print(tokenize(text))
    break
# Out:
# ['I', 'did', 'not', 'recognize', 'the', 'initial', 'symptoms', 'of', 'depression', 'so', 'it', 'took', 'the', 'inability', 'to', 'function', 'for', 'me', 'to', 'see', 'a', 'Dr', 'who', 'then', 'diagnosed', 'me', 'with', 'it']
# []
# []
# []
# ['Mental', 'Health', 'Disease', 'is', 'more', 'common', 'than', 'you', 'think']
# ['Happy', 'Wednesday', 'friends']
# []
# ['Is', 'Laughter', 'Still', 'the', 'Best', 'Medicine', 'via']
# ['Is', 'Laughter', 'Still', 'the', 'Best', 'Medicine']
# ['is', 'the', 'best', 'way', 'to', 'lift', 'your', 'mood', 'Doing', 'something', 'kind', 'and', 'helpful', 'for', 'others', 'is', 'the', 'perfect']
# []
# []
# ['You', 'only', 'have', 'control', 'over', 'yourself', 'and', 'how', 'you', 'choose', 'to', 'be', 'as', 'a', 'person']
# []
# []
# []
# ['Rules', 'for', 'finding', 'happiness']
# ['Good', 'morning', 'beautiful', 'people', 'Have', 'an', 'amazing', 'day']
# []
# ['It', 's', 'not', 'about', 'you']
# ['How', 'do', 'we', 'become', 'a', 'wounded', 'healer']
# []
# ['Believe', 'In', 'Who', 'You', 'Are']
# []
# []
# []
# ['Make', 'it', 'a', 'great', 'Monday', 'Have', 'a', 'productive', 'week']
# []
# []
# ['As', 'you', 'prepare', 'for', 'the', 'upcoming', 'week', 'remember', 'this']
# []
# []
# ['Take', 'time', 'to', 'enjoy', 'yourself', 'when', 'you', 'are', 'away', 'from', 'work', 'Release', 'your', 'anxiety', 'stress', 'Be', 'present', 'in', 'the', 'moment']
# []
# ['Have', 'a', 'beautiful', 'day', 'friends']
# ['I', 've', 'used', 'the', 'technique', 'and', 'found', 'it', 'be', 'be', 'helpful']
# ['Have', 'you', 'ever', 'tried', 'a', 'Grounding', 'Technique', 'to', 'shift', 'your', 'focus']
# ['I', 'changed', 'my', 'settings', 'so', 'only', 'friends', 'of', 'friends', 'can', 'send', 'requests', 'because', 'I', 'had', 'gotten', 'friend', 'requests', 'from', 'a', 'few', 'creepers', 'No', 'thank', 'you']
# ['Peace', 'be', 'with', 'you', 'as', 'you', 'sleep', 'tonight', 'and', 'every', 'night']
# ['The', 'best', 'way', 'to', 'overcome', 'overthinking', 'is', 'to', 'believe', 'in', 'yourself', 'Trust', 'your', 'instincts', 'Follow', 'your', 'heart']
# []
# ['rainn', 'org', 'Rape', 'Abuse', 'Incest', 'National', 'Network']
# []
# ['More', 'than', 'million', 'cases', 'of', 'PTSD', 'are', 'diagnosed', 'per', 'year', 'in', 'the', 'USA', 'alone', 'PTSD', 'can', 'be', 'diagnosed', 'and', 'treated', 'by']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# ['Healthy', 'Tips', 'on', 'how', 'to', 'be', 'Mentally', 'Strong']
# ['Have', 'a', 'fantastic', 'weekend', 'Happy', 'Saturday']
# []
# []
# ['What', 'is', 'your', 'go', 'to', 'comfort', 'food', 'Please', 'comment', 'and', 'share', 'with', 'us', 'Mine', 'is', 'definitely', 'Chocolate', 'Yum']
# []
# []
# ['Have', 'a', 'great', 'day', 'everyone', 'It', 's', 'Friday']
# ['Sleep', 'well']
# ['PTSD', 'or', 'Posttraumatic', 'Stress', 'Disorder', 'is', 'a', 'psychiatric', 'disorder', 'that', 'can', 'occur', 'following', 'the', 'experience', 'or']
# []
# []
# ['So', 'awesome', 'and', 'inspirational', 'A', 'day', 'thoughse', 'students', 'will', 'never', 'forget']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# ['A', 'relaxing', 'pre', 'sleep', 'tip']
# ['Trust', 'your', 'instincts', 'Trust', 'your', 'intuition', 'Follow', 'your', 'heart']
# []
# ['Spread', 'kindness', 'everywhere', 'You', 'may', 'just', 'save', 'a', 'life']
# []
# ['Introduce', 'these', 'simple', 'strategies', 'into', 'your', 'life', 'and', 'you', 'will', 'feel', 'the', 'benefits']
# []
# ['Happy', 'Wednesday', 'friends', 'Embrace', 'the', 'day']
# []
# ['Depression', 'disorders', 'make', 'one', 'feel', 'exhausted', 'worthless', 'helpless', 'and', 'hopeless', 'Such', 'negative', 'thoughughts', 'and']
# []
# ['Please', 'text', 'if', 'you', 'are', 'in', 'crisis', 'Trained', 'counselors', 'are', 'waiting', 'to', 'help', 'you', 'You', 'are', 'not', 'alone']
# ['This', 'too', 'shall', 'pass']
# []
# []
# ['Dad', 'do', 'you', 'have', 'a', 'few', 'minutes', 'to', 'talk', 'written', 'by', 'Rick', 'Strait']
# []
# ['Click', 'like', 'if', 'you', 've', 'experienced', 'this', 'thoughught']
# ['Don', 't', 'be', 'so', 'hard', 'on', 'yourself', 'You', 'are', 'doing', 'the', 'best', 'you', 'can']
# []
# []
# []
# ['Stress', 'less', 'and', 'embrace', 'the', 'goodness', 'the', 'day', 'has', 'to', 'offer']
# ['Create', 'something', 'amazing', 'this', 'week', 'Happy', 'Wednesday']
# []
# []
# ['Every', 'day', 'we', 'need', 'to', 'silence', 'that', 'monster', 'and', 'not', 'give', 'in', 'to', 'the', 'negativity', 'it', 'spews']
# []
# ['There', 'is', 'freedom', 'in', 'forgiveness']
# []
# ['Not', 'All', 'Pain', 'Is', 'Physical']
# []
# []
# ['Thank', 'you', 'to', 'Emily', 'for', 'giving', 'me', 'her', 'permission', 'to', 'share', 'her', 'video', 'She', 'created', 'it', 'to', 'bring', 'attention', 'to', 'issues']
# ['Perspective', 'is', 'a', 'gift']
# ['Enjoy', 'a', 'relaxing', 'day', 'with', 'friends', 'and', 'family']
# []
# ['This', 'mental', 'tug', 'of', 'war', 'is', 'not', 'only', 'frustrating', 'but', 'draining', 'as', 'well', 'Making', 'simple', 'decisions', 'or', 'concentrating']
# ['Practice', 'every', 'single', 'day']
# []
# []
# ['Have', 'a', 'wonderful', 'weekend', 'friends', 'Kat', 'Nat']
# ['Please', 'remember', 'you', 'are', 'not', 'alone', 'You', 'matter', 'and', 'your', 'life', 'matters', 'Please', 'text', 'if', 'you', 'are', 'in', 'crisis', 'and']
# ['Just', 'a', 'friendly', 'reminder']
# []
# []
# []
# []
# []
# []
# []
# ['Happy', 'Friendship', 'Friday', 'Share', 'this', 'post', 'with', 'your', 'friends', 'to', 'wish', 'them', 'a', 'HAPPY', 'day']
# ['Tomorrow', 'is', 'another', 'opportunity', 'to', 'fill', 'our', 'day', 'with', 'and']
# ['Please', 'remember', 'you', 'are', 'not', 'alone', 'Text', 'if', 'you', 'are', 'in', 'crisis', 'is', 'at', 'your', 'fingertips']
# []
# ['It', 's', 'your', 'time', 'to', 'soar']
# ['Live', 'your', 'best', 'life']
# ['Every', 'day', 'choices', 'Good', 'morning']
# ['Enjoy', 'these', 'positive', 'affirmations', 'to', 'relax', 'your', 'soul', 'Sweet', 'Dreams', 'sweet', 'souls']
# ['Possible', 'Trigger', 'Warning']
# []
# ['Healthy', 'tips', 'to']
# ['Did', 'you', 'know', 'that', 'if', 'you', 'text', 'home', 'to', 'when', 'you', 'are', 'depressed', 'suicidal', 'or', 'just', 'needing', 'someone', 'to', 'talk']
# []
# ['To', 'worry', 'or', 'not', 'to', 'worry']
# ['We', 'are', 'passing', 'on', 'some', 'Wednesday', 'love', 'Help', 'yourself', 'to', 'some', 'love', 'and', 'share', 'this', 'post', 'passing', 'the', 'love', 'on', 'to']
# ['Have', 'a', 'relaxing', 'and', 'peaceful', 'evening', 'friends']
# []
# []
# []
# ['We', 'become', 'what', 'we', 'think', 'Keep', 'thoughse', 'thoughughts', 'as', 'positive', 'as', 'possible']
# ['Some', 'healthy', 'tips', 'to', 'boost', 'our', 'confidence']
# ['Have', 'a', 'Thankful', 'Tuesday', 'friends']
# ['Have', 'a', 'peaceful', 'and', 'restful', 'evening']
# []
# []
# ['Why', 'Not', 'You']
# ['Nothing', 'great', 'happens', 'with', 'everyone', 's', 'approval', 'Make', 'choices', 'that', 'best', 'suit', 'you', 'and', 'watch', 'your', 'confidence', 'soar']
# []
# []
# ['Good', 'Morning']
# []
# ['Confidential', 'and', 'Free']
# ['Stay', 'strong', 'You', 'got', 'this']
# ['g', 'your', 'iggety', 'oasis', 'in', 'middle', 'of', 'html', 'm', 'article', 'by']
# []
# []
# ['Celebrate', 'your', 'journey', 'Find', 'the', 'goodness', 'along', 'the', 'way']
# []
# ['Much', 'love', 'and', 'many', 'blessings', 'for', 'a', 'happy', 'Sunday', 'Kat', 'Nat']
# ['is', 'available']
# []
# []
# []
# []
# []
# ['Happy', 'Saturday', 'everyone']
# []
# []
# ['May', 'we', 'all', 'surround', 'ourselves', 'with', 'compassionate', 'and', 'positive', 'people', 'May', 'we', 'also', 'provide', 'the', 'same']
# []
# []
# ['Love', 'friendship', 'to', 'all', 'Kat', 'Nat']
# ['Congratulations', 'Almost', 'to', 'your', 'one', 'year', 'mark', 'My', 'daughter', 'has', 'been', 'years', 'clean', 'now', 'She', 'says', 'a', 'hot', 'shower', 'helps', 'her', 'to', 'resist', 'her', 'urges']
# ['My', 'husband', 'I', 'expected', 'tough', 'times', 'for', 'our', 'kids', 'in', 'high', 'school', 'but', 'middle', 'school', 'was', 'the', 'hardest', 'Sadly', 'his', 'response', 'is', 'accurate']
# ['He', 's', 'not', 'a', 'smart', 'man']
# ['That', 's', 'how', 'I', 'read', 'it']
# ['Excellent', 'idea', 'I', 'lived', 'with', 'gradually', 'increasing', 'symptoms', 'of', 'depression', 'for', 'months', 'because', 'I', 'was', 'unaware', 'that', 'they', 'were', 'all', 'connected']
# []
# []
# []
# []
# []
# []
# []
# ['A', 'Morning', 'is', 'a', 'Wonderful', 'Blessing']
# []
# []
# ['Good', 'Morning']
# []
# []
# []
# ['Sometimes', 'the', 'hardest', 'thing', 'and', 'the', 'right', 'thing', 'are', 'the', 'same']
# []
# []
# ['No', 'way']
# []
# []
# []
# []
# []
# []
# []
# ['I', 'choose']
# []
# ['Happy', 'Tuesday']
# []
# []
# []
# []
# ['But', 'I', 'lived', 'through', 'it', 'and', 'it', 'made', 'me', 'who', 'I', 'am', 'today']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['Start', 'to', 'set', 'yourself', 'free', 'of', 'fear', 'and', 'its', 'negativity', 'You', 'have', 'the', 'strength', 'within', 'you', 'to', 'make', 'it', 'happen']
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['fortunate', 'to', 'be', 'alive']
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# ['My', 'To', 'Do', 'List', 'For', 'Today']
# []
# []
# ['It', 's', 'never', 'to', 'late', 'to', 'pursue', 'a', 'new', 'goal', 'or', 'a', 'new', 'dream', 'if', 'you', 'have', 'the', 'strength', 'determination', 'to', 'do', 'it']
# ['Wishing', 'you', 'a', 'wonderful', 'Wednesday']
# ['Best', 'wishes', 'for', 'a', 'Wonderful', 'Wednesday']
# []
# []
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# ['ain', 't', 'nobody', 'got', 'time', 'for', 'that']
# []
# []
# []
# []
# ['Happy', 'Monday', 'everyone', 'Enjoy', 'your', 'week']
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# ['Celebrate', 'who', 'you', 'are', 'Get', 'your', 'creative', 'on']
# ['to', 'thoughse', 'around', 'you', 'today']
# ['Good', 'morning', 'friends', 'Have', 'a', 'beautiful', 'day']
# ['ind', 'of', 'investment', 'are', 'you', 'willing', 'html', 'm', 'What', 'Kind', 'of', 'Investment', 'Are', 'You', 'Willing', 'to', 'Make', 'to', 'Get', 'What', 'You', 'Want', 'by']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# ['Crisis', 'Text', 'Line', 'information', 'included', 'on', 'high', 'school', 'ID', 'cards', 'in', 'Davis', 'California', 'Hopefully', 'other', 'high', 'schools']
# ['Crisis', 'Text', 'Line', 'information', 'added', 'to', 'high', 'school', 'ID', 'cards', 'in', 'Davis', 'California']
# []
# ['Have', 'a', 'beautiful', 'blessed', 'day', 'everyone']
# ['Made', 'their', 'graduation', 'all', 'about', 'him', 'So', 'presidential', 'Cry', 'me', 'a', 'river']
# ['Please', 'call', 'the', 'number', 'below', 'if', 'you', 'are', 'in', 'crisis', 'Help', 'is', 'available', 'to', 'you']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['can', 'cleanse', 'the', 'soul']
# []
# []
# ['Good', 'morning', 'friends', 'Have', 'a', 'beautiful', 'day', 'filled', 'with', 'hope', 'and', 'happiness']
# ['If', 'you', 'are', 'in', 'crisis', 'please', 'text', 'and', 'ask', 'for', 'help', 'You', 'are', 'not', 'alone', 'Help', 'is', 'at', 'your', 'fingertips']
# []
# ['Strive', 'for', 'progress', 'NOT', 'perfection', 'Perfection', 'is', 'a', 'myth']
# ['Your', 'life', 'has', 'value', 'meaning', 'and', 'purpose']
# []
# []
# []
# ['Different', 'types', 'of', 'depressions']
# []
# ['Wishing', 'you', 'a', 'happy', 'blessed', 'day']
# ['Great', 'things', 'happen', 'from', 'the', 'inside']
# []
# []
# ['Wholly', 'appropriate', 'is', 'not', 'a', 'satisfactory', 'answer']
# ['Grounding', 'helps', 'with', 'anxiety', 'anger', 'and', 'focus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['It', 's', 'A', 'New', 'Week', 'Happy', 'Monday']
# []
# []
# []
# ['Happy', 'Mother', 's', 'Day', 'to', 'all', 'who', 'are', 'celebrating', 'today']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['The', 'truth', 'about', 'depression', 'One', 'brave', 'woman', 's', 'story']
# []
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# ['I', 'thoughught', 'feeling', 'not', 'depressed', 'meant', 'happiness', 'until', 'the', 'day', 'I', 'felt', 'genuine', 'joy', 'and', 'realized', 'it', 'had', 'been', 'missing', 'from', 'my', 'life']
# ['Making', 'the', 'decision', 'to', 'try', 'is', 'a', 'victory', 'in', 'and', 'of', 'itself', 'It', 's', 'not', 'about', 'winning', 'or', 'losing', 'Stepping', 'out', 'of', 'your']
# []
# []
# []
# []
# []
# ['Happy', 'Friday']
# ['thoughught', 'you', 'might', 'be', 'interested', 'in', 'watching', 'this', 'video', 'It', 's', 'inspiring', 'LJS']
# []
# []
# []
# []
# []
# []
# []
# ['We', 're', 'almost', 'there']
# []
# []
# []
# []
# []
# ['The', 'only', 'cure', 'for', 'grief', 'is', 'to', 'grieve']
# []
# ['Wishing', 'you', 'a', 'wonderful', 'Wednesday']
# []
# []
# []
# ['The', 'Crisis', 'Text', 'Line', 'is', 'a', 'resource', 'in', 'which', 'you', 'can', 'text', 'with', 'a', 'certified', 'Crisis', 'Counselor', 'if', 'you', 'ever', 'find']
# []
# []
# ['now', 'that', 's', 'ironic']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# []
# []
# ['Stifled', 'Grief', 'How', 'the', 'West', 'Has', 'It', 'Wrong']
# []
# []
# ['Happy', 'Monday']
# []
# []
# []
# []
# []
# []
# ['Most', 'Common', 'Symptoms', 'of', 'Depression']
# ['Congratulations', 'Greg', 'You', 'put', 'your', 'heart', 'and', 'soul', 'into', 'all', 'you', 'do', 'and', 'it', 'is', 'awesome', 'to', 'see', 'your', 'work', 'being', 'recognized']
# []
# []
# ['To', 'feel', 'genuine', 'happiness', 'as', 'opposed', 'to', 'feeling', 'not', 'depressed', 'brought', 'back', 'an', 'emotion', 'I', 'never', 'realized', 'was', 'missing']
# []
# []
# []
# ['What', 'Recovery', 'From', 'Mental', 'Illness', 'Really', 'Looks', 'Like', 'via']
# []
# []
# ['Keep', 'going', 'anyway']
# []
# []
# ['Thank', 'you', 'for', 'sharing', 'Nicola', 's', 'video', 'She', 'has', 'a', 'wonderful', 'voice']
# []
# []
# []
# ['Talk', 'to', 'your', 'doctor', 'or', 'a', 'mental', 'health', 'professional', 'if', 'you', 'feel', 'you', 'are', 'self', 'medicating', 'Help', 'is', 'available']
# ['Symptoms', 'of', 'social', 'anxiety', 'disorder']
# ['Be', 'true', 'to', 'yourself']
# []
# []
# ['Hold', 'your', 'faith', 'close', 'to', 'your', 'heart', 'It', 'will', 'give', 'you', 'the', 'hope', 'you', 'need', 'during', 'the', 'difficult', 'times']
# ['Hello', 'Beautiful', 'people', 'Have', 'a', 'terrific', 'Tuesday', 'Kat', 'Nat']
# []
# []
# []
# []
# ['Healing', 'hugs', 'for', 'you']
# []
# ['Have', 'a', 'wonderful', 'day', 'friends']
# []
# []
# ['Your', 'life', 'matters', 'Your', 'voice', 'matters', 'Your', 'feelings', 'matter']
# []
# ['Love', 'this']
# []
# []
# []
# ['Enjoy', 'your', 'Sunday', 'everyone']
# []
# ['Rules', 'for', 'Staying', 'Positive']
# []
# ['A', 'petition', 'worth', 'signing', 'Netflix', 'Reasons', 'Why', 'Should', 'Include', 'Crisis', 'Hotline', 'on', 'Each', 'Episode', 'easons', 'why', 'should', 'include', 'crisis', 'hotline', 'on', 'each', 'episode', 'recruiter', 'utm_campaign', 'signature_receipt', 'utm_medium', 'twitter', 'utm_source', 'share_petition', 'via']
# []
# ['For', 'thoughse', 'whole', 'live', 'in', 'Bergen', 'County', 'New', 'Jersey', 'who', 'wish', 'to', 'seek', 'recovery']
# []
# []
# []
# ['For', 'assistance', 'in', 'the', 'United', 'States', 'please', 'call', 'this', 'number', 'People', 'care', 'People', 'are', 'listening']
# ['Please', 'reach', 'out', 'if', 'you', 'are', 'in', 'crisis', 'Help', 'is', 'at', 'your', 'fingertips']
# ['of', 'mental', 'illness', 'because', 'I', 've', 'become', 'more', 'self', 'aware', 'I', 'have', 'shared', 'my', 'story', 'to', 'help', 'others', 'have', 'found', 'my', 'life', 's', 'purpose']
# ['Take', 'time', 'out', 'for', 'yourself', 'Rest', 'relax', 'recoup']
# []
# []
# ['Happy', 'Saturday']
# []
# []
# ['people', 'will', 'experience', 'a', 'mental', 'health', 'issue', 'I', 'am', 'the', 'one']
# ['Depression', 'In', 'memory', 'of', 'Robin', 'Williams']
# ['Oh', 'yes', 'Can', 'you', 'relate', 'Click', 'like', 'if', 'you', 'can']
# ['Be', 'the', 'change', 'Reach', 'out', 'to', 'thoughse', 'who', 'are', 'suffering', 'hurting', 'and', 'who', 'are', 'afraid', 'You', 'have', 'the', 'beautiful', 'gift', 'of']
# ['Clear', 'Signs', 'A', 'Narcissist', 'Is', 'Trying', 'To', 'Manipulate', 'You']
# ['You', 'were', 'created', 'to', 'make', 'somebody', 'else', 's', 'life', 'better', 'Share', 'your', 'time', 'talents', 'kindness', 'and', 'friendship', 'with']
# []
# ['Steps', 'to', 'Self', 'Esteem']
# ['Some', 'important', 'information', 'on', 'Suicide', 'Please', 'share', 'this', 'post', 'Suicide', 'awareness', 'is', 'extremely', 'important', 'to']
# ['HappyFriday']
# []
# []
# []
# []
# ['Sending', 'out', 'to', 'anyone', 'who', 'may', 'need', 'them', 'today']
# []
# []
# []
# []
# ['There', 'are', 'two', 'basic', 'motivating', 'forces', 'and']
# []
# ['At', 'some', 'point', 'I', 'have', 'shared', 'it', 'with', 'my', 'employers', 'and', 'it', 'was', 'not', 'a', 'problem', 'I', 'usually', 'wait', 'until', 'I', 'feel', 'comfortable', 'sharing', 'it', 'with', 'them']
# []
# []
# []
# []
# []
# ['If', 'you', 'are', 'reading', 'this', 'then', 'YOU', 'ARE', 'a', 'HERO']
# []
# ['Sadly', 'this', 'is', 'more', 'common', 'than', 'you', 'think', 'If', 'you', 'feel', 'you', 'could', 'be', 'self', 'medicating', 'please', 'talk', 'to', 'your', 'doctor']
# ['Happy', 'Wednesday', 'dear', 'friends', 'Here', 'are', 'some', 'great', 'tips', 'to', 'have', 'a', 'wonderful', 'day', 'and', 'help', 'you', 'get', 'through', 'the']
# []
# []
# []
# []
# []
# []
# ['Good', 'Tuesday', 'Morning']
# []
# []
# []
# []
# []
# []
# []
# ['Have', 'a', 'stress', 'free', 'week', 'Happy', 'Monday', 'morning']
# ['break', 'away', 'from', 'the', 'grip', 'of', 'fear', 'you', 'will', 'be', 'free']
# []
# ['This', 'is', 'one', 'great', 'way', 'to', 'have', 'more', 'peace', 'in', 'your', 'life']
# []
# ['Type', 'yes', 'if', 'you', 'can', 'relate', 'to', 'this']
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# []
# ['Blurred', 'lines', 'Lol']
# []
# ['Don', 't', 'waste', 'your', 'time', 'worrying', 'Increase', 'your', 'faith', 'and', 'it', 'will', 'ease', 'your', 'fear']
# ['Happy', 'Saturday', 'everyone']
# ['Wow', 'Just', 'when', 'you', 'think', 'nothing', 'else', 'could', 'possibly', 'shock', 'you', 'you', 'are', 'proven', 'wrong', 'Friend', 'you', 'had', 'sounds', 'about', 'right']
# []
# []
# []
# []
# []
# ['The', 'i', 'Mpossible', 'Project', 'with', 'Benjamin', 'Tyler']
# []
# []
# []
# []
# ['Happy', 'Friday', 'friends', 'The', 'weekend', 'is', 'nearly', 'here']
# []
# []
# ['And', 'we', 'do', 'the', 'best', 'we', 'can']
# []
# []
# []
# []
# []
# ['Let', 's', 'be', 'kind', 'to', 'one', 'another', 'as', 'we', 'go', 'throughout', 'our', 'day', 'Thank', 'you', 'for', 'supporting', 'our', 'page', 'Kat', 'Nat']
# []
# []
# ['Have', 'a', 'peaceful', 'sleep', 'everyone']
# []
# []
# []
# ['Sending', 'love', 'and', 'hugs', 'your', 'way', 'to', 'get', 'you', 'through', 'the', 'day']
# []
# ['Mental', 'health', 'is', 'just', 'as', 'important', 'as', 'our', 'physical', 'well', 'being']
# ['Happy', 'Wednesday', 'friends']
# []
# []
# []
# []
# ['Signs', 'You', 'Are', 'Being', 'Emotionally', 'Abused']
# ['always', 'come', 'with', 'opposition']
# ['Drop', 'the', 'stress']
# []
# []
# []
# ['Happy', 'Tuesday']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# []
# ['You', 'can', 'steer', 'yourself', 'any', 'direction', 'you', 'choose']
# ['Have', 'a', 'marvellous', 'Monday']
# ['The', 'Day', 'Rule', 'and', 'Suicide']
# ['Thank', 'you', 'Nicole', 'Yori', 'for', 'your', 'honest', 'and', 'heartfelt', 'letter', 'to', 'us', 'all', 'You', 'are', 'an', 'amazing', 'friend', 'parent', 'and']
# []
# []
# ['Suicide', 'can', 'be', 'prevented', 'Please', 'reach', 'out', 'and', 'ask', 'for', 'help', 'Your', 'life', 'matters']
# []
# []
# ['Find', 'Joy', 'in', 'the', 'Ordinary']
# []
# []
# []
# ['Happy', 'Easter', 'friends', 'Wishing', 'you', 'beautiful', 'blessings', 'and', 'much', 'happiness', 'as', 'you', 'enjoy', 'your', 'Sunday']
# []
# []
# []
# ['Important', 'facts', 'regarding', 'Mental', 'Illness']
# ['Important', 'facts', 'regarding', 'Mental', 'Illness']
# []
# []
# ['Have', 'a', 'Super', 'Saturday']
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# ['Your', 'voice', 'matters', 'Your', 'life', 'has', 'a', 'purpose']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['There', 'is', 'a', 'big', 'difference']
# ['I', 'Live']
# ['I', 'Live']
# []
# ['Happy', 'Friday', 'friends', 'Count', 'your', 'blessings', 'as', 'you', 'go', 'throughout', 'your', 'day']
# ['Deciding', 'to', 'try', 'is', 'the', 'true', 'victory']
# ['Face', 'your', 'fears', 'You', 'are', 'stronger', 'than', 'you', 'realize']
# []
# []
# []
# []
# []
# ['A', 'pure', 'loving', 'heart', 'is', 'what', 's', 'important']
# ['A', 'pure', 'loving', 'heart', 'is', 'what', 's', 'important']
# []
# []
# []
# []
# []
# []
# ['Reach', 'out', 'and', 'ask', 'for', 'help', 'Your', 'life', 'matters']
# []
# []
# ['Good', 'morning', 'everyone', 'Have', 'an', 'amazing', 'day']
# ['Good', 'morning', 'everyone', 'Have', 'an', 'amazing', 'day']
# ['Good', 'night', 'friends', 'Have', 'a', 'peaceful', 'sleep']
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# ['Discover', 'your', 'freedom', 'by', 'being', 'true', 'to', 'yourself']
# []
# []
# ['Healthy', 'solutions', 'are', 'possible']
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['Says', 'he', 'won', 't', 'take', 'a', 'salary', 'Squanders', 'tax', 'payers', 'money', 'on', 'Secret', 'Service', 'in', 'locations', 'instead']
# ['Sometimes', 'I', 'know', 'why', 'it', 'happens', 'sometimes', 'I', 'do', 'not', 'The', 'tingling', 'used', 'to', 'freak', 'me', 'out', 'in', 'the', 'beginning', 'especially', 'when', 'it', 'reached', 'my', 'face']
# ['Red', 'pill', 'I', 'am', 'anyway', 'and', 'the', 'money', 'would', 'help', 'pay', 'my', 'children', 's', 'college', 'education']
# ['Sweet', 'dreams', 'Remember', 'your', 'life', 'matters', 'Sending', 'peace', 'and', 'love', 'your', 'way']
# ['Feel', 'confident', 'enough', 'to', 'know', 'you', 'can', 'handle', 'any', 'stress', 'that', 'comes', 'your', 'way']
# []
# []
# []
# []
# ['Wishing', 'you', 'happiness', 'and', 'blessings', 'throughout', 'your', 'day']
# []
# []
# ['James', 'Comey', 'played', 'a', 'sizable', 'role', 'by', 'reopening', 'the', 'investigation', 'into', 'the', 'emails', 'weeks', 'before', 'the', 'election']
# []
# []
# ['The', 'Crisis', 'Text', 'Line', 'is', 'available', 'if', 'you', 'are', 'in', 'need', 'of', 'help', 'Texters', 'names', 'are', 'anonymous', 'and', 'the']
# []
# []
# ['Wisdom']
# ['in', 'yourself', 'Have']
# []
# ['Sweet', 'dreams', 'friends']
# []
# []
# []
# []
# []
# []
# ['Fabulous', 'Friday', 'is', 'finally', 'here', 'Celebrate', 'the', 'day']
# ['Good', 'night', 'everyone']
# []
# []
# []
# []
# []
# []
# []
# ['Blessings', 'to', 'all', 'who', 'are', 'hurting', 'struggling', 'and', 'suffering', 'You', 'matter', 'Your', 'life', 'matters']
# ['Good', 'morning', 'beautiful', 'friends', 'Enjoy', 'this', 'beautiful', 'day']
# []
# ['Sweet', 'dreams']
# ['We', 'love', 'this', 'Music', 'relaxes', 'the', 'mind', 'and', 'gives', 'peace', 'to', 'your', 'soul']
# []
# []
# []
# ['Next', 'Time', 'Your', 'Stressed']
# []
# []
# []
# ['Today', 'is', 'a', 'gift', 'Embrace', 'your', 'friends', 'and', 'family', 'Do', 'the', 'things', 'you', 'love']
# ['Sleep', 'well']
# []
# []
# ['I', 'struggled', 'a', 'long', 'time', 'OKC', 'firefighter', 'in', 'iconic', 'photo', 'retires']
# ['Live', 'happily', 'and', 'live', 'stress', 'free']
# []
# []
# []
# ['Relax', 'breathe', 'and', 'be', 'patient']
# ['Wishing', 'you', 'joy', 'love', 'and', 'good', 'cheer', 'throughout', 'your', 'Tuesday', 'Kat', 'Nat']
# ['Sweet', 'dreams']
# ['This', 'too', 'shall', 'pass', 'Thankfully']
# []
# []
# []
# []
# []
# ['Help', 'is', 'available', 'if', 'you', 'are', 'suffering', 'from', 'mental', 'illness', 'Please', 'talk', 'to', 'your', 'doctor', 'or', 'a', 'mental', 'health']
# []
# ['May', 'your', 'day', 'be', 'filled', 'with', 'happiness', 'and', 'joyful', 'blessings']
# []
# ['Very', 'Good', 'Reasons', 'To', 'Go', 'To', 'Therapy']
# ['Isn', 't', 'that', 'the', 'truth', 'Sweet', 'dreams', 'everyone']
# ['Therapy', 'is', 'what', 'helped', 'me', 'to', 'regain', 'my', 'life', 'after', 'I', 'was', 'diagnosed', 'with', 'anxiety', 'depression', 'It', 'takes', 'time', 'to', 'heal', 'but', 'recovery', 'is', 'possible']
# []
# ['Yes', 'this', 'includes', 'family']
# ['Yes', 'I', 'agree', 'Do', 'you']
# []
# []
# ['Ways', 'to', 'Maintain', 'Good', 'Mental', 'Health']
# []
# []
# ['We', 'make', 'the', 'best', 'of', 'what', 'we', 'have', 'because', 'we', 'have', 'very', 'little', 'control', 'over', 'the', 'things', 'around', 'us', 'We', 'adapt']
# ['Have', 'a', 'great', 'Sunday', 'everyone']
# ['Docz']
# ['Sweet', 'dreams']
# ['Stay', 'strong', 'Always', 'It', 'gets', 'better']
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# []
# []
# []
# ['Don', 't', 'be', 'a', 'prisoner', 'to', 'negative', 'thoughughts', 'Release', 'the', 'things', 'you', 'cannot', 'control', 'It', 'will', 'free', 'you', 'from', 'anger']
# ['Delicious', 'and', 'healthy', 'Bring', 'on', 'the', 'chocolate']
# []
# []
# []
# []
# ['Share', 'your', 'heart', 'your', 'kindness', 'your', 'beautiful', 'smile', 'your', 'friendship', 'your', 'time', 'and', 'your', 'love', 'with', 'thoughse', 'around']
# ['Have', 'a', 'fantastic', 'Friday', 'everyone']
# []
# ['We', 'at', 'Destigmatize', 'Suicide', 'are', 'saddened', 'by', 'the', 'expected', 'passing', 'of', 'Amy', 'Bleuel', 'founder', 'of', 'Project', 'Semicolon', 'She']
# []
# ['If', 'you', 'suffer', 'from', 'panic', 'attacks', 'click', 'like', 'Let', 's', 'show', 'others', 'they', 'are', 'not', 'alone']
# []
# []
# []
# []
# ['You', 'are', 'stronger', 'than', 'you', 'know', 'Don', 't', 'allow', 'the', 'negativity', 'of', 'others', 'inhibit', 'your', 'growth']
# ['March']
# []
# ['Have', 'a', 'beautiful', 'day', 'friends']
# []
# ['This', 'is', 'an', 'amazing', 'list', 'to', 'live', 'by']
# ['Face', 'Everything', 'And', 'Rise']
# ['What', 'matters', 'most', 'is', 'how', 'we', 'live', 'the', 'last', 'chapter', 'of', 'our', 'life']
# ['Be', 'kind', 'and', 'gentle', 'with', 'yourself', 'You', 'are', 'doing', 'the', 'best', 'you', 'can']
# []
# []
# []
# ['Tomorrow', 'is', 'a', 'new', 'day', 'Stay', 'strong', 'and', 'hold', 'onto', 'the', 'hope', 'for', 'a', 'more', 'desirable', 'day']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Have', 'a', 'great', 'day', 'everyone']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# ['have', 'you', 'volunteered', 'over', 'the', 'past', 'years', 'That', 'could', 'fill', 'the', 'gaps']
# []
# []
# ['sorting', 'fact', 'from', 'fiction']
# ['Mental', 'illness', 'is', 'a', 'part', 'of', 'my', 'life']
# []
# []
# ['Thought', 'for', 'the', 'Week']
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# ['Inside', 'Each', 'Of', 'Us', 'Are', 'Two', 'Wolves']
# ['I', 'have', 'found', 'being', 'pleasantly', 'surprised', 'to', 'be', 'more', 'rewarding', 'than', 'having', 'reality', 'stamp', 'upon', 'my', 'expectations', 'Less']
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# ['I', 'agree', 'with', 'you', 'remains', 'consistent', 'in', 'blaming', 'others', 'for', 'his', 'own', 'failures', 'All', 'talk', 'but', 'no', 'action']
# ['the', 'bill', 'has', 'been', 'referred', 'to', 'as', 'Trump', 'Care', 'Someone', 'else', 'is', 'to', 'blame', 'because', 'an', 'unqualified', 'person', 'won', 'the', 'election', 'That', 's', 'bs']
# ['to', 'suggest', 'this', 'is', 'not', 'fault', 'is', 'ridiculous', 'was', 'courting', 'non', 'supporting', 'Republicans', 'failed', 'to', 'change', 'their', 'minds']
# ['it', 'is', 'so', 'nice', 'to', 'have', 'a', 'television', 'network', 'decide', 'the', 'fate', 'of', 'our', 'country', 'to', 'be', 'key', 'resource', 'for', 'information']
# ['I', 'have', 'found', 'my', 'tribe', 'and', 'it', 'has', 'made', 'my', 'life', 'so', 'much', 'happier', 'I', 'm', 'grateful', 'to', 'be', 'loved', 'by', 'thoughse', 'who', 'know', 'understand', 'the', 'real', 'me']
# ['I', 'do', 'not', 'know', 'you', 'but', 'you', 'seem', 'like', 'someone', 'who', 'could', 'brighten', 'anyone', 's', 'day', 'Please', 'reach', 'out', 'for', 'help', 'Your', 'Life', 'Matters']
# ['we', 'are', 'all', 'doing', 'the', 'best', 'we', 'can', 'Surrounding', 'yourself', 'with', 'thoughse', 'who', 'support', 'you', 'unconditionally', 'makes', 'a', 'world', 'of', 'difference']
# []
# ['Who', 'or', 'what', 'did', 'you', 'need']
# []
# ['sometimes', 'when', 'you', 'are', 'angry', 'there', 'are', 'other', 'emotions', 'under', 'the', 'surface', 'Taking', 'the', 'time', 'to']
# ['Aspire', 'To', 'Be', 'A', 'Giver']
# []
# ['on', 'the', 'radio', 'this', 'week', 'they', 'referred', 'to', 'it', 'as', 'Paul', 'Ryan', 'Care', 'I', 'm', 'betting', 'someone', 's', 'ego', 'did', 'not', 'like', 'that']
# []
# ['it', 'begins', 'with', 'you']
# []
# []
# []
# []
# ['I', 'posted', 'a', 'new', 'photo', 'to', 'Facebook']
# []
# []
# []
# []
# []
# []
# []
